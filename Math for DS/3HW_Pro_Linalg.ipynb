# %% [markdown]
# **Домашнее задание "Продвинутая линейная алгебра".**

# %% [markdown]
# Уровень 0:

# %% [markdown]
# **Задание 1**\
# Дан объект в 2D пространстве

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

A = [[-100, -100, 1],
     [-100, 100, 1],
     [100, 100, 1],
     [0, 0, 1],
     [100, -100, 1],
     [-100, -100, 1]]

A = np.array(A)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %% [markdown]
# При помощи линейных отображений:
#
# - Уменьшить объект в два раза
# - Повернуть на 130 градусов
# - Отразить объект относительно прямой y=x (поможет матрица [[0, 1, 0], [1, 0, 0], [0, 0, 1]])

# %%
B = np.array([[0.5,0,0],
              [0,0.5,0],
              [0,0,0.5]])
m = A @ B
x = m[:,0]
y = m[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
C = np.array([[math.cos(130*math.pi/180), -(math.sin(130*math.pi/180)), 0], 
              [math.sin(130*math.pi/180), math.cos(130*math.pi/180), 0], 
              [1, 0,0]])

r = A @ C
x = r[:,0]
y = r[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
D = np.array([[0, 1, 0], 
              [1, 0, 0], 
              [0, 0, 1]])
D
# Out:
# array([[0, 1, 0],
#        [1, 0, 0],
#        [0, 0, 1]])

# %%
p = A @ D
x = p[:,0]
y = p[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %% [markdown]
# Уровень 1:

# %% [markdown]
# **Задание 2**\
# Найдите спектральное разложение матрицы:
#
# m = np.array([[1, 2],
#               [2, 3]])\
# print(m)

# %%
m = np.array([[1, 2],
              [2, 3]])
print(m)
# Out:
# [[1 2]
#  [2 3]]

# %%
v, w = np.linalg.eig(m)

# %%
v
# Out:
# array([-0.23606798,  4.23606798])

# %%
w
# Out:
# array([[-0.85065081, -0.52573111],
#        [ 0.52573111, -0.85065081]])

# %%
D = np.diag(v)
D
# Out:
# array([[-0.23606798,  0.        ],
#        [ 0.        ,  4.23606798]])

# %%
S = w.T
S
# Out:
# array([[-0.85065081,  0.52573111],
#        [-0.52573111, -0.85065081]])

# %%
S.T
# Out:
# array([[-0.85065081, -0.52573111],
#        [ 0.52573111, -0.85065081]])

# %%
np.dot(S.T, S)
# Out:
# array([[ 1.0000000e+00, -1.2127222e-17],
#        [-1.2127222e-17,  1.0000000e+00]])

# %%
np.dot(np.dot(S.T, D), S)
# Out:
# array([[1., 2.],
#        [2., 3.]])
