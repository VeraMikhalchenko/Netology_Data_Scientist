# %% [markdown]
# **Домашнее задание "Основные математические понятия".**

# %% [markdown]
# Уровень 0:

# %% [markdown]
# Представим фильмы в виде бинарных векторов (numpy array) используя следующие признаки:
#
# [Комедия, Боевик, Исторический, Бред Питт, Бенедикт Камбербэтч, Квентин Тарантино]
#
# Игра в имитацию
#
# Ярость
#
# 12 лет рабства
#
# Однажды в Голливуде
#
# film_1 = np.array([0,0,0,0,1,0])      # Игра в имитацию
#
# film_2 = np.array([0,1,0,1,0,0])      # Ярость
#
# film_3 = np.array([0,0,1,1,1,0])      # 12 лет рабства
#
# film_4 = np.array([1,0,0,1,0,1])      # Однажды в Голливуде

# %%
import numpy as np
import sympy as sym

# %%
imitation = np.array([0,0,0,0,1,0])      # Игра в имитацию

hurry = np.array([0,1,0,1,0,0])      # Ярость

twelve_years_slavery = np.array([0,0,1,1,1,0])      # 12 лет рабства

once_at_hollywood = np.array([1,0,0,1,0,1])      # Однажды в Голливуде

# %% [markdown]
# **Задание 1**\
# Найти угол между векторами-фильмами "Ярость" и "12 лет рабства". Результатом будет являться косинусная мера, которую можно использовать для определения похожести векторов.

# %%
np.arccos(np.clip(np.dot(hurry, twelve_years_slavery), -1.0, 1.0))
# Out:
# 0.0

# %% [markdown]
# Уровень 1:

# %% [markdown]
# **Задание 2**\
# Вычислить с помощью Python значение первой производной для функции
# 8x(x + 3)**2 в точке x = 1

# %%
x = sym.Symbol('x')

# %%
res = sym.diff(8 * x * (x + 3)**2, x)
res
# Out:
# 8*x*(2*x + 6) + 8*(x + 3)**2

# %%
res.subs(x, 1)
# Out:
# 192

# %% [markdown]
# **Задание 3**\
# Объединить векторы фильмов в матрицу, где каждый вектор является строкой матрицы. Умножьте вектор [1,2,3,4] на полученную матрицу

# %%
films_matrix = np.vstack((imitation, hurry, twelve_years_slavery, once_at_hollywood))
films_matrix
# Out:
# array([[0, 0, 0, 0, 1, 0],
#        [0, 1, 0, 1, 0, 0],
#        [0, 0, 1, 1, 1, 0],
#        [1, 0, 0, 1, 0, 1]])

# %%
[1,2,3,4] @ films_matrix
# Out:
# array([4, 2, 3, 9, 4, 4])
