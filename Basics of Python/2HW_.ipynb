# %% [markdown]
# **Домашнее задание к лекции "Управляющие конструкции и коллекции. Часть 1"**

# %% [markdown]
# Задание 1

# %%
word = "test"
word_list = list(word)
len_word = len(word_list)

# Код, который выводит на экран: среднюю букву, если число букв в слове нечетное;
# две средних буквы, если число букв четное.

if len_word % 2 == 0:
        el_1 = int(len_word / 2 - 1)
        el_2 = int(len_word / 2)
        result = word_list [el_1] + word_list [el_2]
        print(result)
elif len_word % 2 != 0:
        el = (len_word - 1) / 2
        print(word_list[el])
else:
        print('impossible')
# Out:
# es

# %%
word = "testing"
word_list = list(word)
len_word = len(word_list)

# Код, который выводит на экран: среднюю букву, если число букв в слове нечетное;
# две средних буквы, если число букв четное.

if len_word % 2 == 0:
        el_1 = int(len_word / 2 - 1)
        el_2 = int(len_word / 2)
        result = word_list [el_1] + word_list [el_2]
        print(result)
elif len_word % 2 != 0:
        el = int((len_word - 1) / 2)
        print(word_list[el])
else:
        print('impossible')
# Out:
# t

# %% [markdown]
# Задание 2

# %%
# Программа, которая последовательно запрашивает у пользователя числа (по одному за раз) 
# и после первого нуля выводит сумму всех ранее введенных чисел.

number = int(input("Введите число: "))
sum_num = 0

while number != 0:
        sum_num += number
        number = int(input("Введите число: "))
print(sum_num)
# Out:
# Введите число: 10
# Введите число: 3
# Введите число: 5
# Введите число: 9
# Введите число: 0
# 27

# %% [markdown]
# Задание 3

# %% [markdown]
# Мы делаем MVP dating-сервиса, и у нас есть список парней и девушек.
# Выдвигаем гипотезу: лучшие рекомендации мы получим, если просто отсортируем имена по алфавиту и познакомим людей с одинаковыми индексами после сортировки! Но мы не будем никого знакомить, если кто-то может остаться без пары:

# %%
boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']

if len(boys) == len(girls):
        boys.sort()
        girls.sort()
        ind = 0
        print('Идеальные пары:')
        while ind != int(len(boys)):
                print(boys[ind], 'и', girls[ind])
                ind += 1
else:
        print('Внимание, кто-то может остаться без пары!')
# Out:
# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha

# %%
boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard', 'Michael']
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']

if len(boys) == len(girls):
        boys.sort()
        girls.sort()
        ind = 0
        print('Идеальные пары:')
        while ind != int(len(boys)):
                print(boys[ind], 'и', girls[ind])
                ind += 1
else:
        print('Внимание, кто-то может остаться без пары!')
# Out:
# Внимание, кто-то может остаться без пары!

# %% [markdown]
# Задание 4

# %% [markdown]
# У нас есть список, содержащий информацию о среднедневной температуре в Фаренгейтах за произвольный период по странам (структура данных в примере). Необходимо написать код, который рассчитает среднюю температуру за период в Цельсиях(!) для каждой страны.

# %%
countries_temperature = [
['Thailand', [75.2, 77, 78.8, 73.4, 68, 75.2, 77]],
['Germany', [57.2, 55.4, 59, 59, 53.6]],
['Russia', [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]],
['Poland', [50, 50, 53.6, 57.2, 55.4, 55.4]]
]

ind = 0
while ind != len(countries_temperature):
        avg_temp_c = round((sum(countries_temperature [ind][1])/len(countries_temperature [ind][1]) - 32) * 5/9, 1)
        country = countries_temperature[ind][0]
        print(country, avg_temp_c, 'C')
        ind += 1
# Out:
# Thailand 23.9 C
# Germany 13.8 C
# Russia 3.7 C
# Poland 12.0 C

# %% [markdown]
# Задание 5
#
# Дан поток логов по количеству просмотренных страниц для каждого пользователя. Вам необходимо написать алгоритм, который считает среднее значение просмотров на пользователя. Т. е. надо посчитать отношение суммы всех просмотров к количеству уникальных пользователей.

# %%
stream = [
'2018-01-01,user1,3',
'2018-01-07,user1,4',
'2018-03-29,user1,1',
'2018-04-04,user1,13',
'2018-01-05,user2,7',
'2018-06-14,user3,4',
'2018-07-02,user3,10',
'2018-03-21,user4,19',
'2018-03-22,user4,4',
'2018-04-22,user4,8',
'2018-05-03,user4,9',
'2018-05-11,user4,11',
]

ind = 0
views_all = 0
user_list = []

while ind != len(stream):
        el = str(stream [ind]).split(',')
        views = int(el[2])
        user_list.append(el[1])
        ind += 1
        views_all += views
        
avg_views_user = views_all / len(set(user_list))
print('Среднее количество просмотров на уникального пользователя:', round(avg_views_user, 2))
# Out:
# Среднее количество просмотров на уникального пользователя: 23.25

# %%
stream = [
'2018-01-01,user100,150',
'2018-01-07,user99,205',
'2018-03-29,user1001,81'
]

ind = 0
views_all = 0
user_list = []

while ind != len(stream):
        el = str(stream [ind]).split(',')
        views = int(el[2])
        user_list.append(el[1])
        ind += 1
        views_all += views
              
avg_views_user = views_all / len(set(user_list))
print('Среднее количество просмотров на уникального пользователя:', round(avg_views_user, 2))
# Out:
# Среднее количество просмотров на уникального пользователя: 145.33

# %% [markdown]
# Задание 6

# %% [markdown]
# Необходимо у пользователя запрашивать набор чисел разделенных пробелом. В результате в отсортированном порядке должны выводиться числа, которые повторяются в вводе более одного раза.

# %%
numbers = input("Введите набор чисел, разделённых пробелом: ")

numbers_list = numbers.split(' ')
new_list = list()

for el in numbers_list:
        if numbers_list.count(el) > 1:
                new_list.append(int(el))

unique = list(set(new_list))
unique.sort()
str_unique = ' '.join (str(x) for x in unique)
print(str_unique)
# Out:
# Введите набор чисел, разделённых пробелом: 1 3 5 7 7 5 2 4
# 5 7
